# %%
import pandas as pd

df_payments = pd.read_csv("../data/raw/olist_order_payments_dataset.csv", sep=",", usecols=['order_id','payment_value'])
df_orders = pd.read_csv("../data/raw/orders_dataset.csv", sep=",", usecols=['order_id','order_approved_at'])

df_merged = df_orders.merge(df_payments, how="inner", on='order_id')
df_merged['order_approved_at'] = pd.to_datetime(df_merged['order_approved_at']).dt.floor('D')
df_merged['order_approved_at'] = df_merged['order_approved_at']
df_sum = df_merged.groupby('order_approved_at')[['payment_value']].sum()

# %%
# Out:
#                    payment_value
# order_approved_at
# 2016-10-04               2877.21
# 2016-10-05               2356.44
# 2016-10-06              20145.72
# 2016-10-07              12185.05
# 2016-10-08               6324.35

# %%
import plotly.express as px

fig = px.line(df_sum, x=df_sum.index, y="payment_value")
fig.show()

# %%
import pandas as pd

# %%
pay = pd.read_csv("../data/raw/order_payments_dataset.csv")
pay['payment_sequential'] = pay['payment_sequential'].astype(int)

# %%
odr = pd.read_csv("../data/raw/order_items_dataset.csv")\
.drop_duplicates(subset=['order_id'], keep='first')
print(odr[odr['order_id'] == '0008288aa423d2a3f00fcb17cd7d8719'])

rev = pd.read_csv("../data/raw/order_reviews_dataset.csv")\
.drop_duplicates(subset=['review_id'], keep='first')
print(rev[rev['review_id'] == '3242cc306a9218d0377831e175d62fbf'])
# Out:
#                             order_id  order_item_id  \
# 13  0008288aa423d2a3f00fcb17cd7d8719              1
#
#                           product_id                         seller_id  \
# 13  368c6c730842d78016ad823897a372db  1f50f920176fa81dab994f9023523100
#
#     shipping_limit_date  price  freight_value
# 13  2018-02-21 02:55:52   49.9          13.37
#                              review_id                          order_id  \
# 1009  3242cc306a9218d0377831e175d62fbf  711246846695fa895c1776f0ddc30b20
#
#       review_score review_comment_title review_comment_message  \
# 1009             5                  NaN                 Ótimo
#
#      review_creation_date review_answer_timestamp
# 1009  2017-07-21 00:00:00     2017-07-22 01:06:37

# %%
pay.to_csv('../data/raw/order_payments_dataset-2.csv', index=False)
odr.to_csv('../data/raw/order_items_dataset-2.csv', index=False)
rev.to_csv('../data/raw/order_reviews_dataset-2.csv', index=False)

# %%
prd = pd.read_csv("../data/raw/products_dataset.csv")
prd_cat = pd.read_csv("../data/raw/product_category_name_translation.csv")

for i in prd['product_category_name'].unique():
    if not i in prd_cat['product_category_name'].unique():
        prd_cat['product_category_name'].add(i)
# Out:
# nan
# pc_gamer
# portateis_cozinha_e_preparadores_de_alimentos
